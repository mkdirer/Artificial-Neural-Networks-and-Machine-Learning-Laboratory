# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense,GRU

# %%
epochs = 30
batch_size = 10
hidden_dims = 32

# %% [markdown]
# # Rastragin

# %%
def rastragin(X):
    A = 10.0
    delta = [x**2 - A * np.cos(2 * np.pi * x) for x in X]
    y = A + sum(delta)
    return [y]

input_data = np.random.random((1000, 10)) # 1000 sequences of length 10
output_data = np.apply_along_axis(rastragin, 1, input_data)
output_data = output_data / np.max(output_data)

train_size = int(len(input_data) * 0.8)
X_train, X_test = input_data[:train_size], input_data[train_size:]
y_train, y_test = output_data[:train_size], output_data[train_size:]

model = Sequential()
model.add(GRU(hidden_dims, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mae')

model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

predictions = model.predict(X_test)
# Out:
# Epoch 1/30
# 80/80 [==============================] - 7s 22ms/step - loss: 0.1912
# Epoch 2/30
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1902
# Epoch 3/30
# 80/80 [==============================] - 1s 13ms/step - loss: 0.1890
# Epoch 4/30
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1890
# Epoch 5/30
# 80/80 [==============================] - 1s 17ms/step - loss: 0.1891
# Epoch 6/30
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1883
# Epoch 7/30
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1881
# Epoch 8/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.1877
# Epoch 9/30
# 80/80 [==============================] - 1s 17ms/step - loss: 0.1857
# Epoch 10/30
# 80/80 [==============================] - 2s 20ms/step - loss: 0.1857
# Epoch 11/30
# 80/80 [==============================] - 1s 11ms/step - loss: 0.1866
# Epoch 12/30
# 80/80 [==============================] - 1s 7ms/step - loss: 0.1840
# Epoch 13/30
# 80/80 [==============================] - 1s 7ms/step - loss: 0.1827
# Epoch 14/30
# 80/80 [==============================] - 1s 8ms/step - loss: 0.1825
# Epoch 15/30
# 80/80 [==============================] - 1s 8ms/step - loss: 0.1810
# Epoch 16/30
# 80/80 [==============================] - 1s 9ms/step - loss: 0.1737
# Epoch 17/30
# 80/80 [==============================] - 1s 7ms/step - loss: 0.1566
# Epoch 18/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1497
# Epoch 19/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1230
# Epoch 20/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1010
# Epoch 21/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1005
# Epoch 22/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0991
# Epoch 23/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0897
# Epoch 24/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0902
# Epoch 25/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0886
# Epoch 26/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0888
# Epoch 27/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0799
# Epoch 28/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0782
# Epoch 29/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0788
# Epoch 30/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0806
# 7/7 [==============================] - 0s 3ms/step

# %%
import matplotlib.pyplot as plt

# narysuj dane testowe
plt.plot(y_test, label='True values')

# narysuj przewidywane wartości
plt.plot(predictions, label='Predictions')

plt.title('Predictions vs True values')
plt.legend()
plt.show()

# %% [markdown]
# # Ackley

# %%
def ackley(x):
    a = 20
    b = 0.2
    c = 2 * np.pi
    d = len(x)
    sum1 = -a * np.exp(-b * np.sqrt(1/d * np.sum(x**2)))
    sum2 = -np.exp(1/d * np.sum(np.cos(c*x)))
    return sum1 + sum2 + a + np.exp(1)

input_data = np.random.uniform(low=-5.0, high=5.0, size=(1000, 2)) # 1000 samples of 2-dimensional data
output_data = np.apply_along_axis(ackley, 1, input_data)
output_data = output_data / np.max(output_data)

train_size = int(len(input_data) * 0.8)
X_train, X_test = input_data[:train_size], input_data[train_size:]
y_train, y_test = output_data[:train_size], output_data[train_size:]

model = Sequential()
model.add(GRU(hidden_dims, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mae')

model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

predictions = model.predict(X_test)
# Out:
# Epoch 1/30
# 80/80 [==============================] - 3s 4ms/step - loss: 0.2460
# Epoch 2/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0617
# Epoch 3/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0557
# Epoch 4/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0514
# Epoch 5/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0503
# Epoch 6/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0504
# Epoch 7/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0496
# Epoch 8/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0478
# Epoch 9/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0477
# Epoch 10/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0478
# Epoch 11/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0462
# Epoch 12/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0440
# Epoch 13/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0436
# Epoch 14/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0416
# Epoch 15/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0418
# Epoch 16/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0411
# Epoch 17/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0410
# Epoch 18/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0393
# Epoch 19/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0394
# Epoch 20/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0390
# Epoch 21/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0391
# Epoch 22/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0375
# Epoch 23/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0376
# Epoch 24/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0363
# Epoch 25/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0365
# Epoch 26/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0366
# Epoch 27/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0371
# Epoch 28/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0355
# Epoch 29/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0358
# Epoch 30/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0353
# 7/7 [==============================] - 0s 3ms/step

# %%
import matplotlib.pyplot as plt

# narysuj dane testowe
plt.plot(y_test, label='True values')

# narysuj przewidywane wartości
plt.plot(predictions, label='Predictions')

plt.title('Predictions vs True values')
plt.legend()
plt.show()

# %% [markdown]
# # Rosenbrock

# %%
def rosenbrock(x):
    return np.sum(100 * (x[1:] - x[:-1]**2)**2 + (1 - x[:-1])**2)

input_data = np.random.uniform(low=-2.0, high=2.0, size=(1000, 2)) # 1000 samples of 2-dimensional data
output_data = np.apply_along_axis(rosenbrock, 1, input_data)
output_data = output_data / np.max(output_data)

train_size = int(len(input_data) * 0.8)
X_train, X_test = input_data[:train_size], input_data[train_size:]
y_train, y_test = output_data[:train_size], output_data[train_size:]

model = Sequential()
model.add(GRU(hidden_dims, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mae')

model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

predictions = model.predict(X_test)
# Out:
# Epoch 1/30
# 80/80 [==============================] - 2s 3ms/step - loss: 0.0995
# Epoch 2/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0834
# Epoch 3/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0721
# Epoch 4/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0666
# Epoch 5/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0641
# Epoch 6/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0597
# Epoch 7/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0557
# Epoch 8/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0516
# Epoch 9/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0465
# Epoch 10/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0433
# Epoch 11/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0379
# Epoch 12/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0360
# Epoch 13/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0348
# Epoch 14/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0334
# Epoch 15/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0329
# Epoch 16/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0315
# Epoch 17/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0321
# Epoch 18/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0311
# Epoch 19/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0304
# Epoch 20/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0296
# Epoch 21/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0270
# Epoch 22/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0271
# Epoch 23/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 24/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0241
# Epoch 25/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0226
# Epoch 26/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0206
# Epoch 27/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0194
# Epoch 28/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0183
# Epoch 29/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0183
# Epoch 30/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0178
# 7/7 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt

# narysuj dane testowe
plt.plot(y_test, label='True values')

# narysuj przewidywane wartości
plt.plot(predictions, label='Predictions')

plt.title('Predictions vs True values')
plt.legend()
plt.show()
