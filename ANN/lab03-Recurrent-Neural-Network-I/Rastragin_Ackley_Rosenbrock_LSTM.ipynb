# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, LSTM

# %%
epochs = 30
batch_size = 10
hidden_dims = 32

# %% [markdown]
# # Rastragin

# %%
def rastragin(X):
    A = 10.0
    delta = [x**2 - A * np.cos(2 * np.pi * x) for x in X]
    y = A + sum(delta)
    return [y]

input_data = np.random.random((1000, 10)) # 1000 sequences of length 10
output_data = np.apply_along_axis(rastragin, 1, input_data)
output_data = output_data / np.max(output_data)

train_size = int(len(input_data) * 0.8)
X_train, X_test = input_data[:train_size], input_data[train_size:]
y_train, y_test = output_data[:train_size], output_data[train_size:]

model = Sequential()
model.add(LSTM(hidden_dims, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mae')

model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

predictions = model.predict(X_test)
# Out:
# Epoch 1/30
# 80/80 [==============================] - 10s 24ms/step - loss: 0.2452
# Epoch 2/30
# 80/80 [==============================] - 2s 23ms/step - loss: 0.2394
# Epoch 3/30
# 80/80 [==============================] - 2s 24ms/step - loss: 0.2384
# Epoch 4/30
# 80/80 [==============================] - 2s 24ms/step - loss: 0.2393
# Epoch 5/30
# 80/80 [==============================] - 2s 27ms/step - loss: 0.2380
# Epoch 6/30
# 80/80 [==============================] - 1s 17ms/step - loss: 0.2380
# Epoch 7/30
# 80/80 [==============================] - 1s 11ms/step - loss: 0.2385
# Epoch 8/30
# 80/80 [==============================] - 1s 10ms/step - loss: 0.2380
# Epoch 9/30
# 80/80 [==============================] - 1s 10ms/step - loss: 0.2383
# Epoch 10/30
# 80/80 [==============================] - 1s 10ms/step - loss: 0.2379
# Epoch 11/30
# 80/80 [==============================] - 1s 12ms/step - loss: 0.2366
# Epoch 12/30
# 80/80 [==============================] - 1s 8ms/step - loss: 0.2355
# Epoch 13/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2361
# Epoch 14/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2357
# Epoch 15/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2358
# Epoch 16/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2340
# Epoch 17/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2308
# Epoch 18/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2280
# Epoch 19/30
# 80/80 [==============================] - 1s 6ms/step - loss: 0.2224
# Epoch 20/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2115
# Epoch 21/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.2054
# Epoch 22/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1693
# Epoch 23/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.1679
# Epoch 24/30
# 80/80 [==============================] - 1s 9ms/step - loss: 0.1544
# Epoch 25/30
# 80/80 [==============================] - 1s 8ms/step - loss: 0.1483
# Epoch 26/30
# 80/80 [==============================] - 1s 9ms/step - loss: 0.1503
# Epoch 27/30
# 80/80 [==============================] - 1s 8ms/step - loss: 0.1517
# Epoch 28/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.1450
# Epoch 29/30
# 80/80 [==============================] - 0s 6ms/step - loss: 0.1366
# Epoch 30/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1337
# 7/7 [==============================] - 0s 3ms/step

# %%
import matplotlib.pyplot as plt

# narysuj dane testowe
plt.plot(y_test, label='True values')

# narysuj przewidywane wartości
plt.plot(predictions, label='Predictions')

plt.title('Predictions vs True values')
plt.legend()
plt.show()

# %% [markdown]
# # Ackley

# %%
def ackley(x):
    a = 20
    b = 0.2
    c = 2 * np.pi
    d = len(x)
    sum1 = -a * np.exp(-b * np.sqrt(1/d * np.sum(x**2)))
    sum2 = -np.exp(1/d * np.sum(np.cos(c*x)))
    return sum1 + sum2 + a + np.exp(1)

input_data = np.random.uniform(low=-5.0, high=5.0, size=(1000, 2)) # 1000 samples of 2-dimensional data
output_data = np.apply_along_axis(ackley, 1, input_data)
output_data = output_data / np.max(output_data)

train_size = int(len(input_data) * 0.8)
X_train, X_test = input_data[:train_size], input_data[train_size:]
y_train, y_test = output_data[:train_size], output_data[train_size:]

model = Sequential()
model.add(LSTM(hidden_dims, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mae')

model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

predictions = model.predict(X_test)
# Out:
# Epoch 1/30
# 80/80 [==============================] - 2s 3ms/step - loss: 0.3562
# Epoch 2/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0452
# Epoch 3/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0427
# Epoch 4/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0410
# Epoch 5/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0402
# Epoch 6/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0397
# Epoch 7/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0387
# Epoch 8/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0388
# Epoch 9/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0390
# Epoch 10/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0374
# Epoch 11/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0362
# Epoch 12/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0351
# Epoch 13/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0347
# Epoch 14/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0343
# Epoch 15/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0348
# Epoch 16/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0340
# Epoch 17/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0361
# Epoch 18/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0334
# Epoch 19/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0330
# Epoch 20/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0334
# Epoch 21/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0325
# Epoch 22/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0328
# Epoch 23/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0326
# Epoch 24/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0316
# Epoch 25/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0326
# Epoch 26/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0328
# Epoch 27/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0323
# Epoch 28/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0318
# Epoch 29/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0315
# Epoch 30/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0323
# 7/7 [==============================] - 0s 3ms/step

# %%
import matplotlib.pyplot as plt

# narysuj dane testowe
plt.plot(y_test, label='True values')

# narysuj przewidywane wartości
plt.plot(predictions, label='Predictions')

plt.title('Predictions vs True values')
plt.legend()
plt.show()

# %% [markdown]
# # Rosenbrock

# %%
def rosenbrock(x):
    return np.sum(100 * (x[1:] - x[:-1]**2)**2 + (1 - x[:-1])**2)

input_data = np.random.uniform(low=-2.0, high=2.0, size=(1000, 2)) # 1000 samples of 2-dimensional data
output_data = np.apply_along_axis(rosenbrock, 1, input_data)
output_data = output_data / np.max(output_data)

train_size = int(len(input_data) * 0.8)
X_train, X_test = input_data[:train_size], input_data[train_size:]
y_train, y_test = output_data[:train_size], output_data[train_size:]

model = Sequential()
model.add(LSTM(hidden_dims, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mae')

model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

predictions = model.predict(X_test)
# Out:
# Epoch 1/30
# 80/80 [==============================] - 2s 4ms/step - loss: 0.1002
# Epoch 2/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0877
# Epoch 3/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0762
# Epoch 4/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0663
# Epoch 5/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0583
# Epoch 6/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0539
# Epoch 7/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0482
# Epoch 8/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0445
# Epoch 9/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0412
# Epoch 10/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0373
# Epoch 11/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0336
# Epoch 12/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0320
# Epoch 13/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0305
# Epoch 14/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0297
# Epoch 15/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0283
# Epoch 16/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0267
# Epoch 17/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0263
# Epoch 18/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0243
# Epoch 19/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0227
# Epoch 20/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0215
# Epoch 21/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0203
# Epoch 22/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0183
# Epoch 23/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0172
# Epoch 24/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0146
# Epoch 25/30
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0122
# Epoch 26/30
# 80/80 [==============================] - 0s 4ms/step - loss: 0.0104
# Epoch 27/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0084
# Epoch 28/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0077
# Epoch 29/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0082
# Epoch 30/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.0072
# 7/7 [==============================] - 1s 3ms/step

# %%
import matplotlib.pyplot as plt

# narysuj dane testowe
plt.plot(y_test, label='True values')

# narysuj przewidywane wartości
plt.plot(predictions, label='Predictions')

plt.title('Predictions vs True values')
plt.legend()
plt.show()
