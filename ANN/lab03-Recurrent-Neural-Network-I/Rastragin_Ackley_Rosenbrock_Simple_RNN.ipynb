# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense

# %%
epochs = 30
batch_size = 10
hidden_dims = 32

# %% [markdown]
# # Rastragin

# %%
def rastragin(X):
    A = 10.0
    delta = [x**2 - A * np.cos(2 * np.pi * x) for x in X]
    y = A + sum(delta)
    return [y]

input_data = np.random.random((1000, 10)) # 1000 sequences of length 10
output_data = np.apply_along_axis(rastragin, 1, input_data)
output_data = output_data / np.max(output_data)

train_size = int(len(input_data) * 0.8)
X_train, X_test = input_data[:train_size], input_data[train_size:]
y_train, y_test = output_data[:train_size], output_data[train_size:]

model = Sequential()
model.add(SimpleRNN(hidden_dims, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1, activation="linear"))
model.compile(optimizer='adam', loss="mae")

model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

predictions = model.predict(X_test)
# Out:
# Epoch 1/30
# 80/80 [==============================] - 1s 2ms/step - loss: 0.2136
# Epoch 2/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2070
# Epoch 3/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2063
# Epoch 4/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2073
# Epoch 5/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2089
# Epoch 6/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2032
# Epoch 7/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.2012
# Epoch 8/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1985
# Epoch 9/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1961
# Epoch 10/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1922
# Epoch 11/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1909
# Epoch 12/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1905
# Epoch 13/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1856
# Epoch 14/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1754
# Epoch 15/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1737
# Epoch 16/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1662
# Epoch 17/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1565
# Epoch 18/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1586
# Epoch 19/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1587
# Epoch 20/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1493
# Epoch 21/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1457
# Epoch 22/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1349
# Epoch 23/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1382
# Epoch 24/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1373
# Epoch 25/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1382
# Epoch 26/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1257
# Epoch 27/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1296
# Epoch 28/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1292
# Epoch 29/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1214
# Epoch 30/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1198
# 7/7 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt

# narysuj dane testowe
plt.plot(y_test, label='True values')

# narysuj przewidywane wartości
plt.plot(predictions, label='Predictions')

plt.title('Predictions vs True values')
plt.legend()
plt.show()

# %% [markdown]
# # Ackley

# %%
def ackley(x):
    a = 20
    b = 0.2
    c = 2 * np.pi
    d = len(x)
    sum1 = -a * np.exp(-b * np.sqrt(1/d * np.sum(x**2)))
    sum2 = -np.exp(1/d * np.sum(np.cos(c*x)))
    return sum1 + sum2 + a + np.exp(1)

input_data = np.random.uniform(low=-5.0, high=5.0, size=(1000, 2)) # 1000 samples of 2-dimensional data
output_data = np.apply_along_axis(ackley, 1, input_data)
output_data = output_data / np.max(output_data)

train_size = int(len(input_data) * 0.8)
X_train, X_test = input_data[:train_size], input_data[train_size:]
y_train, y_test = output_data[:train_size], output_data[train_size:]

model = Sequential()
model.add(SimpleRNN(hidden_dims, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mae')

model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

predictions = model.predict(X_test)
# Out:
# Epoch 1/30
# 80/80 [==============================] - 1s 2ms/step - loss: 0.4658
# Epoch 2/30
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2203
# Epoch 3/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1810
# Epoch 4/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1385
# Epoch 5/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0954
# Epoch 6/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0543
# Epoch 7/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0446
# Epoch 8/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0427
# Epoch 9/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0452
# Epoch 10/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0423
# Epoch 11/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0442
# Epoch 12/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0407
# Epoch 13/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0407
# Epoch 14/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0394
# Epoch 15/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0396
# Epoch 16/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0399
# Epoch 17/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0417
# Epoch 18/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0375
# Epoch 19/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 20/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0431
# Epoch 21/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0437
# Epoch 22/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0410
# Epoch 23/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 24/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0397
# Epoch 25/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0400
# Epoch 26/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0368
# Epoch 27/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0389
# Epoch 28/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0383
# Epoch 29/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0383
# Epoch 30/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0394
# 7/7 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt

# narysuj dane testowe
plt.plot(y_test, label='True values')

# narysuj przewidywane wartości
plt.plot(predictions, label='Predictions')

plt.title('Predictions vs True values')
plt.legend()
plt.show()

# %% [markdown]
# # Rosenbrock

# %%
def rosenbrock(x):
    return np.sum(100 * (x[1:] - x[:-1]**2)**2 + (1 - x[:-1])**2)

input_data = np.random.uniform(low=-2.0, high=2.0, size=(1000, 2)) # 1000 samples of 2-dimensional data
output_data = np.apply_along_axis(rosenbrock, 1, input_data)
output_data = output_data / np.max(output_data)

train_size = int(len(input_data) * 0.8)
X_train, X_test = input_data[:train_size], input_data[train_size:]
y_train, y_test = output_data[:train_size], output_data[train_size:]

model = Sequential()
model.add(SimpleRNN(hidden_dims, input_shape=(X_train.shape[1], 1)))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mae')

model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

predictions = model.predict(X_test)
# Out:
# Epoch 1/30
# 80/80 [==============================] - 1s 2ms/step - loss: 0.3282
# Epoch 2/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0958
# Epoch 3/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0859
# Epoch 4/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0808
# Epoch 5/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0722
# Epoch 6/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0663
# Epoch 7/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0594
# Epoch 8/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0559
# Epoch 9/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0564
# Epoch 10/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0543
# Epoch 11/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0531
# Epoch 12/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0512
# Epoch 13/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0493
# Epoch 14/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0510
# Epoch 15/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0482
# Epoch 16/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0485
# Epoch 17/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0491
# Epoch 18/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0488
# Epoch 19/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0455
# Epoch 20/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0460
# Epoch 21/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0489
# Epoch 22/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0470
# Epoch 23/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0472
# Epoch 24/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0473
# Epoch 25/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0468
# Epoch 26/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0471
# Epoch 27/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0446
# Epoch 28/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0479
# Epoch 29/30
# 80/80 [==============================] - 0s 1ms/step - loss: 0.0464
# Epoch 30/30
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0452
# 7/7 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt

# narysuj dane testowe
plt.plot(y_test, label='True values')

# narysuj przewidywane wartości
plt.plot(predictions, label='Predictions')

plt.title('Predictions vs True values')
plt.legend()
plt.show()
