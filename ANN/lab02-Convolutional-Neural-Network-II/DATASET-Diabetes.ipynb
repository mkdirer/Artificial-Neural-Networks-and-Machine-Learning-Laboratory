# %% [markdown]
# # DATASET [DIABETES](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_diabetes.html#sklearn.datasets.load_diabetes)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split

# Przygotowanie danych
data = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2, random_state=42)

# Normalizacja danych
mean = X_train.mean(axis=0)
std = X_train.std(axis=0)
X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

# Konfiguracja modelu
model = keras.Sequential([
    keras.layers.Reshape(target_shape=(10, 1), input_shape=(10,)),
    keras.layers.Conv1D(filters=32, kernel_size=3, activation='relu'),
    keras.layers.MaxPooling1D(pool_size=2),
    keras.layers.Flatten(),
    keras.layers.Dense(units=64, activation='relu'),
    keras.layers.Dense(units=1)
])

# Kompilacja modelu
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# Trening modelu
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=0)

# Testowanie modelu
test_loss, test_mae = model.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 3847.5454 - mae: 50.7568
# 1/1 [==============================] - 0s 63ms/step
# Test MAE: 50.7568244934082
# Prediction for X_new: [[82.878944]]

# %%
predictions = model.predict(X_test)
# Pętla wyświetlająca dane wejściowe i odpowiadające im predykcje
for i in range(len(X_test)):
    print("Input data:", X_test[i])
    print("Prediction:", predictions[i])
    print("Actual value:", y_test[i])
    print("-----------------------------")
# Out:
# 3/3 [==============================] - 0s 3ms/step
# Input data: [ 0.94879413 -0.94217861 -0.16822504 -0.35492475  2.63158584  2.649166
#   0.42948695  0.71103773  0.65360061 -0.14718605]
# Prediction: [171.42493]
# Actual value: 219.0
# -----------------------------
# Input data: [ 1.96942617 -0.94217861  0.74501508  0.42754112 -0.51143404 -0.33328244
#   0.03763145 -0.83545839 -0.4969087  -0.49013439]
# Prediction: [147.92558]
# Actual value: 70.0
# -----------------------------
# Input data: [ 1.34134492  1.06136988 -0.12256303 -0.28379148  2.17022512  1.04272578
#   1.21319795 -0.06221033  1.74360703 -0.4043973 ]
# Prediction: [188.08423]
# Actual value: 202.0
# -----------------------------
# Input data: [ 2.04793633 -0.94217861  1.06464912  1.61333258  1.16099856  0.78595869
#  -1.60816166  2.95345711  2.04001396  1.22460733]
# Prediction: [295.54752]
# Actual value: 230.0
# -----------------------------
# Input data: [ 0.24220272  1.06136988 -0.46502808 -0.0703917   0.81497802  1.13489858
#  -0.11911075  0.71103773 -0.13312789 -0.23292313]
# Prediction: [127.85834]
# Actual value: 111.0
# -----------------------------
# Input data: [ 0.16369256 -0.94217861 -0.55635209 -0.56832453  2.08371999  1.99737263
#   1.52668235 -0.06221033 -0.47343282  0.11002521]
# Prediction: [131.96439]
# Actual value: 84.0
# -----------------------------
# Input data: [-0.22885822  1.06136988  3.57605945  0.2852746   0.64196775  0.72670475
#  -0.43259515  0.71103773  0.67917597  0.62444773]
# Prediction: [269.4516]
# Actual value: 242.0
# -----------------------------
# Input data: [-0.54289885  1.06136988  0.9276631   0.42754112  2.31440035  1.88544851
#   0.03763145  0.71103773  1.52793425  1.22460733]
# Prediction: [211.28372]
# Actual value: 272.0
# -----------------------------
# Input data: [-2.03459183  1.06136988 -1.94904327 -1.20852388 -0.51143404 -0.62296839
#  -0.11911075 -0.06221033  0.47819947  0.02428813]
# Prediction: [116.15296]
# Actual value: 94.0
# -----------------------------
# Input data: [-1.32800041  1.06136988  0.28839502 -0.42605801  0.78614298  1.02955823
#   0.42948695 -0.06221033 -0.66925607 -0.06144896]
# Prediction: [122.238144]
# Actual value: 96.0
# -----------------------------
# Input data: [-0.93544963 -0.94217861 -0.73900011 -0.49719127  0.98798829  0.89129903
#   1.21319795 -0.52615916 -0.56886325 -0.83308273]
# Prediction: [91.960556]
# Actual value: 94.0
# -----------------------------
# Input data: [ 0.08518241 -0.94217861 -1.26411318 -0.49719127 -1.40532042 -1.41960472
#  -1.13793505 -0.06221033  0.87270889 -1.77619067]
# Prediction: [122.64358]
# Actual value: 252.0
# -----------------------------
# Input data: [-1.95608167 -0.94217861 -1.33260619 -0.56832453 -1.14580502 -1.12991878
#   0.89971355 -1.60870645 -1.9923036  -1.17603107]
# Prediction: [105.129295]
# Actual value: 99.0
# -----------------------------
# Input data: [ 0.39922304  1.06136988  0.26556402  1.28114025  0.32478226  0.44360258
#  -0.98119285  0.71103773  0.95153442  1.82476692]
# Prediction: [200.61938]
# Actual value: 297.0
# -----------------------------
# Input data: [-0.30736838  1.06136988 -1.21845117 -0.0703917  -0.56910413 -0.5966333
#   0.42948695 -0.83545839 -0.38258304  0.88165898]
# Prediction: [124.562355]
# Actual value: 135.0
# -----------------------------
# Input data: [-0.77842932  1.06136988  0.08291599 -0.14152496 -1.5206606  -1.30109684
#  -0.11911075 -0.83545839 -0.97654206  0.62444773]
# Prediction: [138.02452]
# Actual value: 67.0
# -----------------------------
# Input data: [ 0.87028398  1.06136988  1.47560717  0.14300808  0.81497802  0.35142978
#  -0.35422405  0.71103773  1.51152021  1.73902984]
# Prediction: [203.19144]
# Actual value: 295.0
# -----------------------------
# Input data: [ 1.34134492  1.06136988  1.84090322  1.42340678  0.44012244  0.80571001
#  -1.05956395  1.4842858   0.58794447  1.48181858]
# Prediction: [244.07999]
# Actual value: 264.0
# -----------------------------
# Input data: [-0.69991916  1.06136988  0.56236706  1.42340678 -2.64522735 -2.22940861
#  -1.13793505 -1.01330544 -0.66925607  0.28149938]
# Prediction: [207.83266]
# Actual value: 170.0
# -----------------------------
# Input data: [ 1.02730429  1.06136988  1.20163514  1.42340678  0.29594722  0.45018635
#  -0.43259515  0.71103773  0.43525578  0.53871064]
# Prediction: [185.7591]
# Actual value: 275.0
# -----------------------------
# Input data: [-1.56353089 -0.94217861  0.79067709 -0.71059105 -0.25191863 -0.70855741
#  -0.51096625 -0.06221033  1.39280475 -0.31866022]
# Prediction: [148.30553]
# Actual value: 310.0
# -----------------------------
# Input data: [ 1.02730429 -0.94217861 -0.94447914 -1.13739061  0.95915324  1.06906086
#   0.74297135 -0.06221033 -0.56886325 -1.34750524]
# Prediction: [100.08032]
# Actual value: 64.0
# -----------------------------
# Input data: [-0.93544963 -0.94217861 -1.08146516 -0.78172431 -0.13657846 -0.4583741
#   1.84016675 -0.83545839 -1.41762153  0.11002521]
# Prediction: [89.86742]
# Actual value: 128.0
# -----------------------------
# Input data: [ 1.26283476  1.06136988  0.44821204  0.99660721  0.3536173   0.26584075
#  -0.27585295 -0.06221033  0.80247209  0.36723647]
# Prediction: [155.69244]
# Actual value: 232.0
# -----------------------------
# Input data: [-1.32800041 -0.94217861  0.9048321  -0.42605801 -0.19424854 -0.14235307
#   0.50785805 -0.83545839 -0.5934843  -0.23292313]
# Prediction: [123.6998]
# Actual value: 129.0
# -----------------------------
# Input data: [ 0.87028398  1.06136988  0.26556402  0.85434069 -0.62677422 -0.01067765
#  -0.90282175 -0.06221033 -0.72155194  0.28149938]
# Prediction: [148.11063]
# Actual value: 118.0
# -----------------------------
# Input data: [ 0.63475351  1.06136988  1.22446614  1.13887373 -0.45376395  0.04199252
#  -0.66770845 -0.06221033 -0.54462392 -0.4043973 ]
# Prediction: [159.20284]
# Actual value: 263.0
# -----------------------------
# Input data: [ 0.79177382  1.06136988 -0.41936607  1.35227352 -1.05929989 -0.33328244
#  -1.60816166  0.71103773 -0.27455579 -0.31866022]
# Prediction: [189.7374]
# Actual value: 77.0
# -----------------------------
# Input data: [-1.24949026 -0.94217861 -1.60657822 -1.06625735 -0.51143404 -0.97190827
#   1.99690895 -1.60870645 -1.30634964 -1.0045569 ]
# Prediction: [105.38694]
# Actual value: 48.0
# -----------------------------
# Input data: [ 0.32071288  1.06136988 -0.48785908 -0.21265822  0.72847289  1.02297446
#   0.03763145 -0.06221033 -0.29574135  0.45297355]
# Prediction: [118.29492]
# Actual value: 107.0
# -----------------------------
# Input data: [ 0.55624335 -0.94217861  1.93222723 -1.11391664  0.18060704  0.85179641
#  -0.58933735  0.43266843 -1.03799926  0.36723647]
# Prediction: [185.53165]
# Actual value: 140.0
# -----------------------------
# Input data: [-2.2701223  -0.94217861 -0.83032412 -0.56832453  0.06526686  0.43701881
#   0.27274475 -0.06221033 -1.45617543 -0.57587147]
# Prediction: [82.15619]
# Actual value: 113.0
# -----------------------------
# Input data: [-0.07183791  1.06136988  0.26556402 -1.56419018  0.06526686  0.14733287
#  -0.27585295 -0.06221033  0.37647063  0.02428813]
# Prediction: [124.287445]
# Actual value: 90.0
# -----------------------------
# Input data: [ 0.55624335  1.06136988 -0.16822504  0.56980765 -0.33842377 -0.01726142
#  -1.21630615  0.71103773  0.58794447  0.62444773]
# Prediction: [167.08504]
# Actual value: 164.0
# -----------------------------
# Input data: [ 2.04793633 -0.94217861  0.81350809 -1.20852388  0.95915324  1.29290909
#  -0.43259515  0.74970014  0.23733306  0.45297355]
# Prediction: [175.92868]
# Actual value: 180.0
# -----------------------------
# Input data: [-1.7205512   1.06136988  1.61259319  1.06774047  1.65119432  1.37191435
#   0.58622915 -0.06221033  0.82613883 -0.23292313]
# Prediction: [203.67355]
# Actual value: 233.0
# -----------------------------
# Input data: [-0.22885822  1.06136988 -0.69333811 -0.56832453 -0.22308359 -0.00409387
#  -0.43259515 -0.06221033  0.10449389  0.53871064]
# Prediction: [106.19626]
# Actual value: 42.0
# -----------------------------
# Input data: [-0.07183791  1.06136988 -0.73900011 -0.40258403  0.6708028   0.91763412
#  -0.27585295  0.40947099  0.18866353  0.53871064]
# Prediction: [126.20974]
# Actual value: 84.0
# -----------------------------
# Input data: [ 1.41985507  1.06136988 -0.69333811  0.07187482  0.52662757  0.76620738
#  -0.58933735  0.71103773  0.46388491  1.65329275]
# Prediction: [158.50108]
# Actual value: 172.0
# -----------------------------
# Input data: [ 0.39922304 -0.94217861 -1.26411318 -1.20852388 -0.02123828 -0.24769342
#   1.60505345 -0.83545839 -1.30634964 -1.6047165 ]
# Prediction: [91.62597]
# Actual value: 63.0
# -----------------------------
# Input data: [-0.07183791 -0.94217861 -1.51525421 -0.28379148  0.00759677 -0.17527193
#   1.52668235 -0.83545839 -1.34280407  0.7959219 ]
# Prediction: [103.46357]
# Actual value: 48.0
# -----------------------------
# Input data: [ 1.41985507  1.06136988 -0.6705071   1.16234771  0.00759677 -0.31353113
#   1.60505345 -1.0674328  -0.83072436  0.11002521]
# Prediction: [161.04364]
# Actual value: 108.0
# -----------------------------
# Input data: [ 0.87028398  1.06136988 -0.51069008  0.56980765 -1.37648538 -0.93240564
#  -1.29467725 -0.06221033  0.03444795 -1.17603107]
# Prediction: [150.1625]
# Actual value: 156.0
# -----------------------------
# Input data: [ 2.36197696  1.06136988 -0.73900011 -0.49719127 -0.07890837  0.44360258
#  -1.29467725  1.4842858   0.300508    0.88165898]
# Prediction: [172.21597]
# Actual value: 168.0
# -----------------------------
# Input data: [ 0.87028398 -0.94217861 -0.99014114  0.68860019  0.9303182  -0.31353113
#   0.82134245 -0.3096497   1.85678752  0.11002521]
# Prediction: [164.37543]
# Actual value: 90.0
# -----------------------------
# Input data: [-0.38587853 -0.94217861 -0.78466212 -0.56832453  0.69963784  0.37776487
#   2.15365115 -0.83545839 -1.49549276 -1.69045359]
# Prediction: [99.92597]
# Actual value: 52.0
# -----------------------------
# Input data: [-2.11310198 -0.94217861 -0.80749312 -1.56419018 -0.79978448 -0.56371444
#   0.35111585 -0.83545839 -1.57679949 -0.06144896]
# Prediction: [95.47874]
# Actual value: 200.0
# -----------------------------
# Input data: [ 0.63475351 -0.94217861 -1.10429616 -0.0703917  -0.91512466 -1.87388495
#   2.54550666 -1.60870645 -0.4047229   0.02428813]
# Prediction: [149.22348]
# Actual value: 87.0
# -----------------------------
# Input data: [-0.46438869 -0.94217861 -1.83488825 -0.56832453 -0.74211439 -0.70197364
#   0.89971355 -1.09063025 -1.75029202 -1.0045569 ]
# Prediction: [96.484535]
# Actual value: 90.0
# -----------------------------
# Input data: [-1.32800041 -0.94217861 -0.00840802 -0.63945779 -0.13657846 -0.43862279
#   0.27274475 -0.06221033  0.64062207 -1.17603107]
# Prediction: [104.47126]
# Actual value: 258.0
# -----------------------------
# Input data: [ 0.08518241 -0.94217861  1.20163514 -0.92399083 -1.5206606  -1.50519375
#   0.42948695 -1.60870645 -1.10174679 -0.57587147]
# Prediction: [160.15778]
# Actual value: 136.0
# -----------------------------
# Input data: [-2.11310198 -0.94217861 -1.51525421 -1.42192366 -0.39609386 -0.20819079
#   0.35111585 -0.83545839 -1.0070798  -1.69045359]
# Prediction: [81.81724]
# Actual value: 158.0
# -----------------------------
# Input data: [ 0.55624335  1.06136988  0.33405703 -0.71059105 -0.13657846  0.98347183
#  -1.37304835  1.4842858  -2.04459948 -1.26176816]
# Prediction: [148.42813]
# Actual value: 69.0
# -----------------------------
# Input data: [ 0.39922304 -0.94217861 -0.89881713 -0.35492475 -0.1654135  -0.35303376
#   1.13482685 -0.83545839 -0.66925607  0.02428813]
# Prediction: [94.121605]
# Actual value: 72.0
# -----------------------------
# Input data: [-1.1709801   1.06136988 -0.41936607  1.63680656  1.88187467  2.2804748
#  -0.82445065  2.25753386  0.72956324 -0.91881982]
# Prediction: [242.68369]
# Actual value: 171.0
# -----------------------------
# Input data: [-0.621409   -0.94217861  1.33862116 -0.0703917  -0.51143404 -0.34644999
#   0.50785805 -0.83545839 -1.30634964 -1.34750524]
# Prediction: [143.21664]
# Actual value: 95.0
# -----------------------------
# Input data: [-0.54289885 -0.94217861 -1.01297215 -0.71059105  0.69963784  0.77937492
#   0.82134245 -0.06221033 -0.72155194  0.1957623 ]
# Prediction: [83.99551]
# Actual value: 72.0
# -----------------------------
# Input data: [ 0.79177382  1.06136988  1.27012815  0.42754112 -0.91512466 -0.71514119
#  -0.90282175 -0.06221033  0.39135778 -0.4043973 ]
# Prediction: [165.00107]
# Actual value: 151.0
# -----------------------------
# Input data: [-0.621409   -0.94217861 -0.41936607 -0.85285757 -0.05007332 -0.22135833
#   0.82134245 -0.83545839 -0.21271687 -1.17603107]
# Prediction: [87.05584]
# Actual value: 168.0
# -----------------------------
# Input data: [-0.85693947 -0.94217861 -1.19562017 -1.63532344 -0.6844443  -1.80146347
#   3.01573326 -1.60870645 -0.42743535 -0.14718605]
# Prediction: [133.85504]
# Actual value: 60.0
# -----------------------------
# Input data: [-0.54289885 -0.94217861  0.60802906 -0.14152496  1.73769945  1.95128623
#  -0.35422405  1.4842858   0.66638829  0.02428813]
# Prediction: [177.90836]
# Actual value: 122.0
# -----------------------------
# Input data: [-0.93544963 -0.94217861  0.83633909 -0.56832453 -0.65560926 -0.62296839
#  -0.74607955  0.05377688  0.67917597 -0.4043973 ]
# Prediction: [137.93262]
# Actual value: 52.0
# -----------------------------
# Input data: [-1.32800041  1.06136988  1.11031113 -0.42605801 -1.03046484 -1.0114109
#   0.50785805 -0.83545839 -0.94638605 -0.14718605]
# Prediction: [148.38235]
# Actual value: 187.0
# -----------------------------
# Input data: [ 0.32071288  1.06136988 -0.99014114  1.28114025  0.23827713  0.00907367
#   1.36994015 -0.83545839 -0.66925607  0.71018481]
# Prediction: [163.064]
# Actual value: 102.0
# -----------------------------
# Input data: [-0.93544963 -0.94217861 -1.4239302  -0.85285757 -0.10774341  0.31851092
#  -0.90282175  0.71103773  0.12167137 -0.31866022]
# Prediction: [101.11667]
# Actual value: 214.0
# -----------------------------
# Input data: [ 1.57687539 -0.94217861  0.35688803  1.28114025  1.30517378  0.91763412
#   0.19437365 -0.06221033  1.18972879 -1.26176816]
# Prediction: [182.247]
# Actual value: 248.0
# -----------------------------
# Input data: [-1.1709801   1.06136988 -0.28238005  1.13887373  1.1898336   1.54967617
#  -0.82445065  1.4842858   0.61447413 -0.14718605]
# Prediction: [199.63333]
# Actual value: 181.0
# -----------------------------
# Input data: [ 1.10581445  1.06136988 -0.55635209  1.13887373 -0.13657846 -0.0896829
#  -0.43259515 -0.06221033  0.53393085 -0.83308273]
# Prediction: [152.4419]
# Actual value: 110.0
# -----------------------------
# Input data: [-2.34863245 -0.94217861 -0.76183112 -1.42192366 -1.31881529 -1.46569112
#   0.19437365 -0.83545839 -0.03827004 -1.69045359]
# Prediction: [106.08218]
# Actual value: 140.0
# -----------------------------
# Input data: [-1.48502073  1.06136988 -0.30521106 -0.85285757 -0.30958872  0.11441401
#  -1.21630615  0.71103773  0.37647063 -0.74734564]
# Prediction: [135.70453]
# Actual value: 202.0
# -----------------------------
# Input data: [-1.64204104  1.06136988 -0.41936607  0.14300808 -0.39609386 -0.5044605
#  -1.37304835  0.71103773  1.38402515 -0.4043973 ]
# Prediction: [168.14267]
# Actual value: 101.0
# -----------------------------
# Input data: [-0.07183791  1.06136988  0.60802906  1.06774047  0.84381306  1.20732006
#  -0.82445065  1.4842858   0.50625602  0.53871064]
# Prediction: [191.98798]
# Actual value: 222.0
# -----------------------------
# Input data: [ 1.26283476 -0.94217861 -0.48785908  1.77907308  0.95915324  0.68061835
#  -0.98119285  1.4842858   1.63118998  2.76787487]
# Prediction: [244.05978]
# Actual value: 281.0
# -----------------------------
# Input data: [-1.32800041  1.06136988 -0.25954905 -0.33145077 -1.03046484 -0.47812542
#  -1.21630615  0.3244137  -0.23313898 -0.74734564]
# Prediction: [131.64195]
# Actual value: 61.0
# -----------------------------
# Input data: [ 1.41985507 -0.94217861 -1.33260619 -0.85285757 -0.54026908 -0.49787673
#   0.74297135 -0.83545839 -1.20118531 -1.26176816]
# Prediction: [92.88704]
# Actual value: 89.0
# -----------------------------
# Input data: [ 0.16369256  1.06136988 -0.87598613  0.56980765  0.81497802  1.56284372
#  -1.52979055  2.25753386  0.300508   -1.0045569 ]
# Prediction: [197.22433]
# Actual value: 91.0
# -----------------------------
# Input data: [-0.621409    1.06136988  1.24729714  0.99660721  1.79536954  1.83277834
#  -0.04073965  0.71103773  0.76620852  0.96739607]
# Prediction: [202.66698]
# Actual value: 186.0
# -----------------------------
# Input data: [-1.01395979e+00 -9.42178611e-01  7.90677085e-01  7.41559207e-04
#   3.53617305e-01  3.38262238e-01 -5.89337353e-01  5.48655642e-01
#   9.06872981e-01 -5.75871473e-01]
# Prediction: [147.72711]
# Actual value: 220.0
# -----------------------------
# Input data: [ 0.94879413  1.06136988  0.37971903  0.78320743  0.44012244  0.56211046
#   0.19437365 -0.06221033 -0.09457399  0.36723647]
# Prediction: [129.29399]
# Actual value: 237.0
# -----------------------------
# Input data: [ 0.24220272 -0.94217861 -0.46502808 -0.35492475  0.26711217  0.46335389
#  -1.60816166  2.25753386  1.22828268 -0.49013439]
# Prediction: [169.07138]
# Actual value: 233.0
# -----------------------------
# Input data: [-1.87757151 -0.94217861 -0.12256303 -0.21265822 -0.05007332  0.18025172
#   0.50785805 -0.83545839 -1.30634964 -0.31866022]
# Prediction: [85.860985]
# Actual value: 68.0
# -----------------------------
# Input data: [-1.24949026 -0.94217861 -0.28238005 -0.71059105 -0.97279475 -0.98507581
#   0.11600255 -0.83545839 -0.19248562 -1.86192776]
# Prediction: [90.1759]
# Actual value: 190.0
# -----------------------------
# Input data: [-1.09246994 -0.94217861 -1.4010992  -2.13325627 -0.05007332 -0.30694736
#   1.36994015 -0.99784048 -0.72155194 -1.17603107]
# Prediction: [97.0398]
# Actual value: 96.0
# -----------------------------
# Input data: [-0.621409   -0.94217861 -1.30977519 -0.63945779  0.98798829  0.43701881
#   2.62387776 -0.83545839 -1.10174679 -0.23292313]
# Prediction: [115.29188]
# Actual value: 72.0
# -----------------------------
# Input data: [ 0.00667225 -0.94217861 -1.4239302  -0.14152496 -0.13657846 -0.39253639
#   0.89971355 -0.83545839 -0.09457399  0.11002521]
# Prediction: [103.85944]
# Actual value: 153.0
# -----------------------------
# Input data: [ 0.24220272 -0.94217861 -0.57918309 -0.85285757 -0.62677422 -0.93240564
#   1.68342455 -1.60870645 -1.53576441  0.1957623 ]
# Prediction: [110.75788]
# Actual value: 98.0
# -----------------------------
# Input data: [-0.621409   -0.94217861 -1.3782682  -1.06625735 -1.86668114 -2.17673843
#   1.13482685 -1.60870645 -1.20118531 -1.43324233]
# Prediction: [113.97808]
# Actual value: 37.0
# -----------------------------
# Input data: [-0.54289885 -0.94217861 -1.51525421 -1.3507904  -1.23231015 -1.04432975
#   0.42948695 -0.83545839 -1.89171993 -1.09029399]
# Prediction: [83.21772]
# Actual value: 63.0
# -----------------------------
# Input data: [-1.40651057 -0.94217861  0.72218408 -0.49719127 -0.62677422 -0.37936884
#  -0.11911075 -0.06221033 -0.56886325 -1.17603107]
# Prediction: [103.86446]
# Actual value: 184.0
# -----------------------------
