# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.cluster import KMeans

digits = load_digits()
X = digits.data
y = digits.target

plt.gray()
plt.matshow(digits.images[30])
plt.show()

kmeans = KMeans(n_clusters=10)
clusters = kmeans.fit_predict(X)

fig, ax = plt.subplots(2, 5, figsize=(10, 4))
centers = kmeans.cluster_centers_.reshape(10, 8, 8)

for axi, center in zip(ax.flat, centers):
    axi.set(xticks=[], yticks=[])
    axi.imshow(center, interpolation='bicubic', cmap=plt.cm.gray_r)

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.cluster import KMeans

digits = load_digits()
X = digits.data
y = digits.target

plt.gray()
plt.matshow(digits.images[30])
plt.show()

kmeans = KMeans(n_clusters=8)
clusters = kmeans.fit_predict(X)

fig, ax = plt.subplots(2, 4, figsize=(8, 4))
centers = kmeans.cluster_centers_.reshape(8, 8, 8)

for axi, center in zip(ax.flat, centers):
    axi.set(xticks=[], yticks=[])
    axi.imshow(center, interpolation='spline16', cmap=plt.cm.gray_r)

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# !pip install fuzzy-c-means
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: typer
#     Found existing installation: typer 0.7.0
#     Uninstalling typer-0.7.0:
#       Successfully uninstalled typer-0.7.0
# ...

# %%
# !pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 13.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894073 sha256=51ddfac8560eceecda8657e512cb023a7c21bb0418c4d9488c26b76762be596b
#   Stored in directory: /root/.cache/pip/wheels/4f/86/1b/dfd97134a2c8313e519bcebd95d3fedc7be7944db022094bc8
# Successfully built scikit-fuzzy
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
import skfuzzy as fuzz
import numpy as np

digits = load_digits()
X = digits.data
y = digits.target

plt.gray()
plt.matshow(digits.images[30])
plt.show()

n_clusters = 10
cntr, u, u0, d, jm, p, fpc = fuzz.cluster.cmeans(X.T, n_clusters, 2, error=0.005, maxiter=1000)

fig, ax = plt.subplots(2, 5, figsize=(10, 4))
centers = cntr.T.reshape(n_clusters, 8, 8)

for axi, center in zip(ax.flat, centers):
    axi.set(xticks=[], yticks=[])
    axi.imshow(center, interpolation='bicubic', cmap=plt.cm.gray_r)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from skfuzzy.cluster import cmeans
import numpy as np

digits = load_digits()
X = digits.data
y = digits.target

plt.gray()
plt.matshow(digits.images[30])
plt.show()

n_clusters = 10
cntr, u, u0, d, jm, p, fpc = cmeans(X.T, n_clusters, 2, error=0.005, maxiter=1000)

fig, ax = plt.subplots(2, 5, figsize=(10, 4))
centers = cntr.T.reshape(n_clusters, 8, 8)

for axi, center in zip(ax.flat, centers):
    axi.set(xticks=[], yticks=[])
    axi.imshow(center, interpolation='bicubic', cmap=plt.cm.gray_r)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from skfuzzy.cluster import cmeans
import numpy as np

digits = load_digits()
X = digits.data
y = digits.target

plt.gray()
plt.matshow(digits.images[30])
plt.show()

n_clusters = 10
cntr, u, u0, d, jm, p, fpc = cmeans(X.T, n_clusters, 2, error=0.005, maxiter=1000)

fig, ax = plt.subplots(2, 5, figsize=(10, 4))
centers = cntr.T.reshape(n_clusters, 8, 8)

for axi, center in zip(ax.flat, centers):
    axi.set(xticks=[], yticks=[])
    axi.imshow(center, interpolation='bicubic', cmap=plt.cm.gray_r)

plt.tight_layout()

fig2, ax2 = plt.subplots()
ax2.set_title('Fuzzy Membership Matrix')
ax2.set_xlabel('Cluster')
ax2.set_ylabel('Sample')
im2 = ax2.imshow(u, cmap='viridis', aspect='auto')
cbar2 = plt.colorbar(im2, ax=ax2, fraction=0.046, pad=0.04)
cbar2.set_label('Membership Degree')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.cluster import AgglomerativeClustering
import numpy as np

digits = load_digits()
X = digits.data
y = digits.target

n_clusters = 10
clustering = AgglomerativeClustering(n_clusters=n_clusters)
clusters = clustering.fit_predict(X)

fig, ax = plt.subplots(2, 5, figsize=(10, 4))
centers = []
data_counts = np.zeros(n_clusters)  # Licznik danych w poszczególnych klastrach

for i in range(n_clusters):
    cluster_points = X[clusters == i]
    data_counts[i] = len(cluster_points)  # Zliczanie liczby danych w klastrze
    center = cluster_points.mean(axis=0)
    centers.append(center)
    axi = ax[i // 5, i % 5]
    axi.set(xticks=[], yticks=[])
    axi.imshow(center.reshape(8, 8), interpolation='bicubic', cmap=plt.cm.gray_r)

# Wyświetlanie liczby danych na wykresie
for i, axi in enumerate(ax.flat):
    axi.text(0.05, 0.05, f'N={int(data_counts[i])}', transform=axi.transAxes, color='red')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.mixture import GaussianMixture
import numpy as np

digits = load_digits()
X = digits.data
y = digits.target

n_clusters = 10
gmm = GaussianMixture(n_components=n_clusters)
gmm.fit(X)
clusters = gmm.predict(X)

fig, ax = plt.subplots(2, 5, figsize=(10, 4))
centers = gmm.means_

data_counts = np.zeros(n_clusters)  # Licznik danych w poszczególnych klastrach

for i in range(n_clusters):
    cluster_points = X[clusters == i]
    data_counts[i] = len(cluster_points)  # Zliczanie liczby danych w klastrze
    center = centers[i]
    axi = ax[i // 5, i % 5]
    axi.set(xticks=[], yticks=[])
    axi.imshow(center.reshape(8, 8), interpolation='bicubic', cmap=plt.cm.gray_r)

# Wyświetlanie liczby danych na wykresie
for i, axi in enumerate(ax.flat):
    axi.text(0.05, 0.05, f'N={int(data_counts[i])}', transform=axi.transAxes, color='red')

plt.tight_layout()
plt.show()
